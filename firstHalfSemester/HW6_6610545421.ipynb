-- %%
DROP DATABASE IF EXISTS  UnivInfo;
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.037

-- %%
CREATE DATABASE UnivInfo;
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.004

-- %%
use UnivInfo;
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.001

-- %%
CREATE TABLE UnivInfo (
  Stud_ID VARCHAR(10),
  Stud_Name VARCHAR(100),
  Course VARCHAR(100),
  Prof_ID VARCHAR(10),
  Prof_Office VARCHAR(100)
);
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.017

-- %%
INSERT INTO UnivInfo VALUES
('S01','Alice','DB','P10','Room201'),
('S02','Bob','DB','P10','Room201'),
('S01','Alice','Networks','P11','Room305'),
('S03','Alice','OS','P12','Room108');
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.003

-- %%
SELECT * FROM UnivInfo;
-- Out:
-- (4 row(s) affected)
-- Total execution time: 00:00:01.008
-- <table><tr><th>Stud_ID</th><th>Stud_Name</th><th>Course</th><th>Prof_ID</th><th>Prof_Office</th></tr><tr><td>S01</td><td>Alice</td><td>DB</td><td>P10</td><td>Room201</td></tr><tr><td>S02</td><td>Bob</td><td>DB</td><td>P10</td><td>Room201</td></tr><tr><td>S01</td><td>Alice</td><td>Networks</td><td>P11</td><td>Room305</td></tr><tr><td>S03</td><td>Alice</td><td>OS</td><td>P12</td><td>Room108</td></tr></table>

-- %% [markdown]
-- **Decompose UnivInfo to 3NF**
--
-- Tables: Student, Professor, Enrollment

-- %%
CREATE TABLE Student (
  Stud_ID VARCHAR(10) PRIMARY KEY,
  Stud_Name VARCHAR(100)
);
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.025

-- %%
CREATE TABLE Professor (
  Prof_ID VARCHAR(10) PRIMARY KEY,
  Prof_Office VARCHAR(100)
);
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.012

-- %%
CREATE TABLE Enrollment (
  Stud_ID VARCHAR(10),
  Course VARCHAR(100),
  Prof_ID VARCHAR(10),
  PRIMARY KEY (Stud_ID, Prof_ID, Course),
  FOREIGN KEY (Stud_ID) REFERENCES Student(Stud_ID),
  FOREIGN KEY (Prof_ID) REFERENCES Professor(Prof_ID)
);
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.023

-- %%
-- Insert data
INSERT INTO Student VALUES
('S01','Alice'),
('S02','Bob'),
('S03','Alice');

INSERT INTO Professor VALUES
('P10','Room201'),
('P11','Room305'),
('P12','Room108');

INSERT INTO Enrollment VALUES
('S01','DB','P10'),
('S02','DB','P10'),
('S01','Networks','P11'),
('S03','OS','P12');
-- Out:
-- Commands completed successfully
-- Commands completed successfully
-- Commands completed successfully
-- Total execution time: 00:00:00.010

-- %%
-- Check tables
SELECT * FROM Student;
SELECT * FROM Professor;
SELECT * FROM Enrollment;
-- Out:
-- (3 row(s) affected)
-- (3 row(s) affected)
-- (4 row(s) affected)
-- Total execution time: 00:00:03.035
-- <table><tr><th>Stud_ID</th><th>Stud_Name</th></tr><tr><td>S01</td><td>Alice</td></tr><tr><td>S02</td><td>Bob</td></tr><tr><td>S03</td><td>Alice</td></tr></table>
-- <table><tr><th>Prof_ID</th><th>Prof_Office</th></tr><tr><td>P10</td><td>Room201</td></tr><tr><td>P11</td><td>Room305</td></tr><tr><td>P12</td><td>Room108</td></tr></table>
-- <table><tr><th>Stud_ID</th><th>Course</th><th>Prof_ID</th></tr><tr><td>S01</td><td>DB</td><td>P10</td></tr><tr><td>S02</td><td>DB</td><td>P10</td></tr><tr><td>S01</td><td>Networks</td><td>P11</td></tr><tr><td>S03</td><td>OS</td><td>P12</td></tr></table>

-- %% [markdown]
-- With new Assumptions
--
-- A1: No student takes two different course from the same professer
--
-- A2: No course is taught by more than one professor

-- %%
CREATE TABLE Course (
  Course VARCHAR(100) PRIMARY KEY,
  Prof_ID VARCHAR(10),
  FOREIGN KEY (Prof_ID) REFERENCES Professor(Prof_ID)
);
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.038

-- %%
CREATE TABLE Enrollment_c (
  Stud_ID VARCHAR(10),
  Course VARCHAR(100),
  Prof_ID VARCHAR(10),
  PRIMARY KEY (Stud_ID, Course),
  UNIQUE (Stud_ID, Prof_ID),
  FOREIGN KEY (Stud_ID) REFERENCES Student(Stud_ID),
  FOREIGN KEY (Course) REFERENCES Course(Course),
  FOREIGN KEY (Prof_ID) REFERENCES Professor(Prof_ID)
);
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00.034

-- %%
-- Insert courses each taught by exactly one professor
INSERT INTO Course VALUES
('DB','P10'),
('Networks','P11'),
('OS','P12');

-- Insert enrollments valid under new assumptions
INSERT INTO Enrollment_c VALUES
('S01','DB','P10'),
('S02','Networks','P11'),
('S03','OS','P12');
-- Out:
-- Commands completed successfully
-- Commands completed successfully
-- Total execution time: 00:00:00.007

-- %%
SELECT * FROM Course;
SELECT * FROM Enrollment_c;
-- Out:
-- (3 row(s) affected)
-- (3 row(s) affected)
-- Total execution time: 00:00:02.027
-- <table><tr><th>Course</th><th>Prof_ID</th></tr><tr><td>DB</td><td>P10</td></tr><tr><td>Networks</td><td>P11</td></tr><tr><td>OS</td><td>P12</td></tr></table>
-- <table><tr><th>Stud_ID</th><th>Course</th><th>Prof_ID</th></tr><tr><td>S01</td><td>DB</td><td>P10</td></tr><tr><td>S02</td><td>Networks</td><td>P11</td></tr><tr><td>S03</td><td>OS</td><td>P12</td></tr></table>
