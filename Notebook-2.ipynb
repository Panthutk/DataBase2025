-- %%
use admission_6610545421
-- Out:
-- Commands completed successfully
-- Total execution time: 00:00:00

-- %%
select Student.sID, sName, count(Apply.sID) as number_of_apps
from Student Left join Apply
on Student.sID = Apply.sID
group by Student.sID;
-- Out:
-- (12 row(s) affected)
-- Total execution time: 00:00:01.010
-- <table><tr><th>sID</th><th>sName</th><th>number_of_apps</th></tr><tr><td>123</td><td>Amy</td><td>4</td></tr><tr><td>234</td><td>Bob</td><td>1</td></tr><tr><td>345</td><td>Craig</td><td>4</td></tr><tr><td>456</td><td>Doris</td><td>0</td></tr><tr><td>543</td><td>Craig</td><td>1</td></tr><tr><td>567</td><td>Edward</td><td>0</td></tr><tr><td>654</td><td>Amy</td><td>0</td></tr><tr><td>678</td><td>Fay</td><td>1</td></tr><tr><td>765</td><td>Jay</td><td>3</td></tr><tr><td>789</td><td>Gary</td><td>0</td></tr><tr><td>876</td><td>Irene</td><td>3</td></tr><tr><td>987</td><td>Helen</td><td>2</td></tr></table>
